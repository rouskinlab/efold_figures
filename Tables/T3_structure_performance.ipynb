# %%
import pandas as pd
from rouskinhf import get_dataset
import torch
import numpy as np
import os

# %%
result_algos = pd.read_feather('../Figure1/saved_data_plot/results_benchmark_algos.feather')
result_algos.loc[result_algos['dataset']=='viral_fragments', 'dataset'] = 'Viral mRNA'
result_algos.loc[result_algos['dataset']=='lncRNA', 'dataset'] = 'Long ncRNA'
result_algos.loc[result_algos['dataset']=='archiveII', 'dataset'] = 'ArchiveII'
result_algos.loc[result_algos['model']=='UFold', 'model'] = 'UFold (original)'

# %%
ground_truth = pd.DataFrame()

for test_set in ["PDB", "archiveII", "viral_fragments", "lncRNA"]:
    data = get_dataset(test_set, force_download=True)
    data = pd.DataFrame(data).T[['sequence', 'structure']]
    data['dataset'] = test_set

    ground_truth = pd.concat([ground_truth, data])
    del data
# Out:
# PDB: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# PDB: Download complete. File saved at data/PDB/data.json
# archiveII: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# archiveII: Download complete. File saved at data/archiveII/data.json
# viral_fragments: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# viral_fragments: Download complete. File saved at data/viral_fragments/data.json
# lncRNA: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# lncRNA: Download complete. File saved at data/lncRNA/data.json

# %%
def compute_f1(pred_matrix, target_matrix, threshold=0.5):
    """
    Compute the F1 score of the predictions.

    :param pred_matrix: Predicted pairing matrix probability  (L,L)
    :param target_matrix: True binary pairing matrix (L,L)
    :return: F1 score for this RNA structure
    """

    pred_matrix = (pred_matrix > threshold).float()


    TP = torch.sum(pred_matrix*target_matrix)
    PP = torch.sum(pred_matrix)
    P = torch.sum(target_matrix)
    sum_pair = PP + P

    if sum_pair == 0:
        return [1.0, 1.0, 1.0]
    else:
        return [
                (TP / PP).item(),
                (TP / P).item(),
                (2 * TP / sum_pair).item()
                ]
    
def pairList2pairMatrix(pair_list, len_seq):
    pair_list = np.array(pair_list).astype(int)
    pairing_matrix = torch.zeros((len_seq, len_seq))

    if len(pair_list) > 0:
        pairing_matrix[pair_list[:,0], pair_list[:,1]] = 1.0
        pairing_matrix[pair_list[:,1], pair_list[:,0]] = 1.0

    return pairing_matrix

# %%
data_comparison = pd.DataFrame()

path_data = '../Figure5/saved_data_plot/results_V2'

for model in os.listdir(path_data):

    prediction = pd.read_feather(os.path.join(path_data, model)).drop_duplicates(['reference'])

    merged = ground_truth.reset_index().rename(columns={'index': 'reference'}).merge(prediction, on=['sequence', 'reference'], suffixes=('_true', '_pred'))

    F1s = []
    Precisions = []
    Recalls = []
    for i, row in merged.iterrows():
        Precision, Recall, F1 = compute_f1(torch.tensor(np.stack(row['structure_pred'])), 
                                        pairList2pairMatrix(row['structure_true'], len(row['sequence'])), threshold=0.5)
        
        F1s.append(F1)
        Precisions.append(Precision)
        Recalls.append(Recall)

    model = model.split('.feather')[0].split('_')[-1]
    print(model)
    merged['F1'] = F1s
    merged['Precision'] = Precisions
    merged['Recall'] = Recalls
    merged['model'] = model
    print(merged.groupby('dataset')['F1'].mean())

    data_comparison = pd.concat([data_comparison, merged[['reference', 'model', 'dataset', 'F1', 'Precision', 'Recall']]])

data_comparison.loc[data_comparison['model']=='eFoldPT+FT', 'model'] = 'eFold'
data_comparison.loc[data_comparison['model']=='eFoldPT', 'model'] = 'eFold (pre-trained)'
data_comparison.loc[data_comparison['model']=='UFoldPT+FT', 'model'] = 'UFold (re-trained)'

data_comparison.loc[data_comparison['dataset']=='viral_fragments', 'dataset'] = 'Viral mRNA'
data_comparison.loc[data_comparison['dataset']=='lncRNA', 'dataset'] = 'Long ncRNA'
data_comparison.loc[data_comparison['dataset']=='archiveII', 'dataset'] = 'ArchiveII'
# Out:
# eFoldPT
# dataset
# PDB                0.886010
# archiveII          0.584986
# lncRNA             0.400431
# viral_fragments    0.674164
# Name: F1, dtype: float64
# human-mRNA
# dataset
# PDB                0.890150
# archiveII          0.580508
# lncRNA             0.402036
# viral_fragments    0.682623
# Name: F1, dtype: float64
# UFoldPT+FT
# dataset
# PDB                0.890532
# archiveII          0.607041
# lncRNA             0.347520
# viral_fragments    0.674862
# Name: F1, dtype: float64
# eFoldPT+FT
# dataset
# PDB                0.894044
# archiveII          0.599568
# lncRNA             0.442343
# viral_fragments    0.725702
# Name: F1, dtype: float64
# pri-miRNA
# dataset
# PDB                0.891003
# archiveII          0.599262
# lncRNA             0.318432
# viral_fragments    0.707887
# Name: F1, dtype: float64
# UFoldPT
# dataset
# PDB                0.890010
# archiveII          0.603470
# lncRNA             0.377261
# viral_fragments    0.669095
# Name: F1, dtype: float64

# %%
data_comparison.dataset.unique(), result_algos.dataset.unique()
# Out:
# (array(['PDB', 'ArchiveII', 'Viral mRNA', 'Long ncRNA'], dtype=object),
#  array(['PDB', 'ArchiveII', 'Viral mRNA', 'Long ncRNA'], dtype=object))

# %%
results_perf = pd.concat([data_comparison, result_algos.drop(columns=['length', 'structure'])])

results_perf = results_perf[results_perf.model.isin(['UFold (re-trained)', 'eFold (pre-trained)', 'eFold', 'SPOT-RNA', 'UFold (original)'])]#.groupby(['model', 'dataset']).mean()
results_perf
# Out:
#         reference                model     dataset        F1  Precision  \
# 0         2N7X-2D  eFold (pre-trained)         PDB  0.933333   0.875000
# 1         8S95-2D  eFold (pre-trained)         PDB  0.703704   0.666667
# 2         2CD1-2D  eFold (pre-trained)         PDB  1.000000   1.000000
# 3         1WTT-2D  eFold (pre-trained)         PDB  1.000000   1.000000
# 4         2NCI-2D  eFold (pre-trained)         PDB  0.888889   0.800000
# ...           ...                  ...         ...       ...        ...
# 30250     XIST_10             SPOT-RNA  Long ncRNA  0.363919   0.422383
# 30251    MALAT1_0             SPOT-RNA  Long ncRNA  0.221729   0.364964
# 30252     XIST_11             SPOT-RNA  Long ncRNA  0.323917   0.445596
# 30253  NORAD1_55C             SPOT-RNA  Long ncRNA  0.253552   0.347305
# 30254  NORAD1_55C             SPOT-RNA  Long ncRNA  0.253552   0.347305
#
#          Recall       MCC  structure_type
# 0      1.000000       NaN             NaN
# 1      0.745098       NaN             NaN
# 2      1.000000       NaN             NaN
# 3      1.000000       NaN             NaN
# 4      1.000000       NaN             NaN
# ...         ...       ...             ...
# 30250  0.319672  0.367247  <class 'list'>
# 30251  0.159236  0.240774  <class 'list'>
# 30252  0.254438  0.336500  <class 'list'>
# 30253  0.199656  0.263151  <class 'list'>
# 30254  0.199656  0.263151  <class 'list'>
#
# [18964 rows x 8 columns]

# %%
# Group the data by model and dataset and calculate the mean for each group
grouped = results_perf.groupby(['model', 'dataset']).mean(numeric_only=True).reset_index()

# Pivot the table to create a multi-level column structure
pivot_df = pd.pivot_table(grouped, index='model', columns='dataset', values=['Precision', 'Recall', 'F1'])

# Swap the level of the columns to have dataset as the top level and the metrics as the second level
pivot_df = pivot_df.swaplevel(i=0, j=1, axis=1).sort_index(axis=1)

# Define the new order for the models and reorder the rows
new_order = ['SPOT-RNA', 'UFold (original)', 'UFold (re-trained)', 'eFold (pre-trained)', 'eFold']
pivot_df = pivot_df.reindex(new_order)

pivot_df = pivot_df.reindex(columns=pivot_df.columns.reindex(['Precision', 'Recall', 'F1'], level=1)[0])[['PDB', 'ArchiveII', 'Viral mRNA', 'Long ncRNA']]

pivot_df = pivot_df.style\
            .format(precision=3)\
            .highlight_max(axis=0, props="font-weight:bold;font-color:black;")\
            .background_gradient(axis=1, vmin=-0.1, vmax=1, cmap="viridis", text_color_threshold=0)\
            .set_properties(**{'text-align': 'center'})\
            .set_table_styles(
                        [{"selector": "th", "props": [('text-align', 'center')]},
                        ])
pivot_df
# Out:
# <style type="text/css">
# #T_7ddf1 th {
#   text-align: center;
# }
# #T_7ddf1_row0_col0 {
#   background-color: #a8db34;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col1 {
#   background-color: #d2e21b;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col2, #T_7ddf1_row3_col0 {
#   background-color: #b2dd2d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col3 {
#   background-color: #4ec36b;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col4 {
#   background-color: #5ec962;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col5, #T_7ddf1_row2_col7 {
#   background-color: #50c46a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col6 {
#   background-color: #4ac16d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col7 {
#   background-color: #1f9a8a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col8 {
#   background-color: #23a983;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col9 {
#   background-color: #2a788e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col10 {
#   background-color: #365c8d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row0_col11 {
#   background-color: #31668e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col0 {
#   background-color: #8bd646;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col1 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #eae51a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col2 {
#   background-color: #b0dd2f;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col3 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #95d840;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col4 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #bade28;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col5 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #a5db36;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col6, #T_7ddf1_row1_col8 {
#   background-color: #25ac82;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col7, #T_7ddf1_row3_col5 {
#   background-color: #27ad81;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col9 {
#   background-color: #365d8d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col10 {
#   background-color: #3e4989;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row1_col11 {
#   background-color: #3c4f8a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col0 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #c2df23;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col1 {
#   background-color: #cde11d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col2 {
#   background-color: #bddf26;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col3 {
#   background-color: #28ae80;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col4, #T_7ddf1_row3_col4, #T_7ddf1_row3_col6, #T_7ddf1_row4_col4 {
#   background-color: #37b878;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col5 {
#   background-color: #2db27d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col6 {
#   background-color: #42be71;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col8, #T_7ddf1_row3_col8 {
#   background-color: #46c06f;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col9 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #22a785;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col10 {
#   background-color: #306a8e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row2_col11 {
#   background-color: #297a8e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col1, #T_7ddf1_row4_col1 {
#   background-color: #d5e21a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col2, #T_7ddf1_row4_col0 {
#   background-color: #bade28;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col3 {
#   background-color: #21a585;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col7 {
#   background-color: #5ac864;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col9 {
#   background-color: #24878e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row3_col10, #T_7ddf1_row3_col11 {
#   background-color: #25858e;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col2 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #c0df25;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col3 {
#   background-color: #25ab82;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col5 {
#   background-color: #2ab07f;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col6 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #54c568;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col7 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #6ccd5a;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col8 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #5ec962;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col9 {
#   background-color: #20928c;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col10 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #228c8d;
#   color: #000000;
#   text-align: center;
# }
# #T_7ddf1_row4_col11 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #218f8d;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_7ddf1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_7ddf1_level0_col0" class="col_heading level0 col0" colspan="3">PDB</th>
#       <th id="T_7ddf1_level0_col3" class="col_heading level0 col3" colspan="3">ArchiveII</th>
#       <th id="T_7ddf1_level0_col6" class="col_heading level0 col6" colspan="3">Viral mRNA</th>
#       <th id="T_7ddf1_level0_col9" class="col_heading level0 col9" colspan="3">Long ncRNA</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_7ddf1_level1_col0" class="col_heading level1 col0" >Precision</th>
#       <th id="T_7ddf1_level1_col1" class="col_heading level1 col1" >Recall</th>
#       <th id="T_7ddf1_level1_col2" class="col_heading level1 col2" >F1</th>
#       <th id="T_7ddf1_level1_col3" class="col_heading level1 col3" >Precision</th>
#       <th id="T_7ddf1_level1_col4" class="col_heading level1 col4" >Recall</th>
#       <th id="T_7ddf1_level1_col5" class="col_heading level1 col5" >F1</th>
#       <th id="T_7ddf1_level1_col6" class="col_heading level1 col6" >Precision</th>
#       <th id="T_7ddf1_level1_col7" class="col_heading level1 col7" >Recall</th>
#       <th id="T_7ddf1_level1_col8" class="col_heading level1 col8" >F1</th>
#       <th id="T_7ddf1_level1_col9" class="col_heading level1 col9" >Precision</th>
#       <th id="T_7ddf1_level1_col10" class="col_heading level1 col10" >Recall</th>
#       <th id="T_7ddf1_level1_col11" class="col_heading level1 col11" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ddf1_level0_row0" class="row_heading level0 row0" >SPOT-RNA</th>
#       <td id="T_7ddf1_row0_col0" class="data row0 col0" >0.854</td>
#       <td id="T_7ddf1_row0_col1" class="data row0 col1" >0.925</td>
#       <td id="T_7ddf1_row0_col2" class="data row0 col2" >0.873</td>
#       <td id="T_7ddf1_row0_col3" class="data row0 col3" >0.694</td>
#       <td id="T_7ddf1_row0_col4" class="data row0 col4" >0.727</td>
#       <td id="T_7ddf1_row0_col5" class="data row0 col5" >0.695</td>
#       <td id="T_7ddf1_row0_col6" class="data row0 col6" >0.683</td>
#       <td id="T_7ddf1_row0_col7

# %%
from scipy.stats import ttest_ind

ttest_ind(results_perf[(results_perf['model']=='eFold (pre-trained)') & (results_perf['dataset']=='Long ncRNA')]['F1'].tolist(),
          results_perf[(results_perf['model']=='UFold (re-trained)') & (results_perf['dataset']=='Long ncRNA')]['F1'].tolist())
# Out:
# TtestResult(statistic=1.6957539791280387, pvalue=0.09529470245712583, df=58.0)

# %%
pivot_df.to_excel('tables/T3_structure_performance.xlsx')
