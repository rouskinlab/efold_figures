# %%
import pandas as pd
import numpy as np
import torch

import os

from rouskinhf import get_dataset

# %%
def compute_metrics(pred_matrix, target_matrix, threshold=0.5):
    """
    Compute the F1 score of the predictions.

    :param pred_matrix: Predicted pairing matrix probability  (L,L)
    :param target_matrix: True binary pairing matrix (L,L)
    :return: F1 score for this RNA structure
    """

    pred_matrix = (pred_matrix > threshold).float()


    TP = torch.sum(pred_matrix*target_matrix)
    TN = torch.sum((1-pred_matrix)*(1-target_matrix))
    FN = torch.sum((1-pred_matrix)*target_matrix)
    FP = torch.sum(pred_matrix*(1-target_matrix))

    PP = torch.sum(pred_matrix)
    P = torch.sum(target_matrix)
    sum_pair = PP + P

    MCC_denominator = torch.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    MCC = (TP*TN - FP*FN)/MCC_denominator if MCC_denominator != 0 else torch.tensor([0.])

    if sum_pair == 0:
        return [1.0, 1.0, 1.0, 1.0]
    else:
        return [
                (TP / PP).item(),
                (TP / P).item(),
                (2 * TP / sum_pair).item(),
                MCC.item()
                ]
    
def pairList2pairMatrix(pair_list, len_seq):
    pair_list = np.array(pair_list).astype(int)
    pairing_matrix = torch.zeros((len_seq, len_seq))

    if len(pair_list) > 0:
        pairing_matrix[pair_list[:,0], pair_list[:,1]] = 1.0
        pairing_matrix[pair_list[:,1], pair_list[:,0]] = 1.0

    return pairing_matrix

# %%
ground_truth = pd.DataFrame()

for test_set in ["PDB", "archiveII", "viral_fragments", "lncRNA"]:
    data = get_dataset(test_set, force_download=True)
    data = pd.DataFrame(data).T[['sequence', 'structure']]
    data['dataset'] = test_set

    ground_truth = pd.concat([ground_truth, data])
    del data
# Out:
# PDB: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# PDB: Download complete. File saved at data/PDB/data.json
# archiveII: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# archiveII: Download complete. File saved at data/archiveII/data.json
# viral_fragments: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# viral_fragments: Download complete. File saved at data/viral_fragments/data.json
# lncRNA: Downloading dataset from HuggingFace Hub...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# lncRNA: Download complete. File saved at data/lncRNA/data.json

# %%
result_algos = pd.read_feather('../Figure1/saved_data_plot/results_benchmark_algos.feather')
result_algos.loc[result_algos['dataset']=='viral_fragments', 'dataset'] = 'Viral mRNA'
result_algos.loc[result_algos['dataset']=='archiveII_blast', 'dataset'] = 'ArchiveII'

# %%
prediction = pd.read_feather('../Figure5/saved_data_plot/results_V2/test_results_eFoldPT+FT.feather')

merged = ground_truth.reset_index().rename(columns={'index': 'reference'}).merge(prediction, on=['sequence', 'reference'], suffixes=('_true', '_pred'))

f1s = []
mccs = []
precisions = []
recalls = []
for i, row in merged.iterrows():
    precision, recall, F1, MCC = compute_metrics(torch.tensor(np.stack(row['structure_pred'])), 
                                                    pairList2pairMatrix(row['structure_true'], len(row['sequence'])), threshold=0.5)
    
    f1s.append(F1)
    mccs.append(MCC)
    precisions.append(precision)
    recalls.append(recall)

merged['F1'] = f1s
merged['model'] = 'eFold'
merged['Precision'] = precisions
merged['Recall'] = recalls
merged['MCC'] = mccs

merged.loc[merged['dataset']=='viral_fragments', 'dataset'] = 'Viral mRNA'

# %%
result_algos = pd.concat([result_algos, merged[['model', 'dataset', 'Precision', 'Recall', 'F1', 'MCC']]])
result_algos.loc[result_algos['dataset']=='lncRNA', 'dataset'] = 'Long ncRNA'
result_algos.loc[result_algos['model']=='RNAstructure', 'model'] = 'RNAstructure Fold'

# %%
models = ['RNAstructure Fold', 'EternaFold', 'MXFold2', 'UFold', 'E2EFold', 'SPOT-RNA', 'CNNFold', 'NeuralFold', 'RNAformer', 'eFold']
metrics = ['Precision', 'Recall', 'F1', 'MCC']

# Group the data by model and dataset and calculate the mean for each group
grouped = result_algos.groupby(['model', 'dataset']).mean(numeric_only=True).reset_index()

# Pivot the table to create a multi-level column structure
pivot_df = pd.pivot_table(grouped, index='model', columns='dataset', values=metrics)

# Swap the level of the columns to have dataset as the top level and the metrics as the second level
pivot_df = pivot_df.swaplevel(i=0, j=1, axis=1).sort_index(axis=1)

# Define the new order for the models and reorder the rows
pivot_df = pivot_df.reindex(models)

pivot_df = pivot_df.reindex(columns=pivot_df.columns.reindex(metrics, level=1)[0])[['PDB', 'archiveII', 'Viral mRNA', 'Long ncRNA']]

pivot_df = pivot_df.style\
            .format(precision=2)\
            .highlight_max(axis=0, props="font-weight:bold;font-color:black;")\
            .background_gradient(axis=1, vmin=-0.1, vmax=1, cmap="viridis", text_color_threshold=0)\
            .set_properties(**{'text-align': 'center'})\
            .set_table_styles(
                        [{"selector": "th", "props": [('text-align', 'center')]},
                        # {"selector": "tbody td", "props": [("border", "1px solid")]},
                        # {"selector": "th", "props": [("border", "1px solid")]}
                        ])
pivot_df
# Out:
# <style type="text/css">
# #T_4baeb th {
#   text-align: center;
# }
# #T_4baeb_row0_col0 {
#   background-color: #c2df23;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col1, #T_4baeb_row1_col1 {
#   background-color: #cae11f;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col2, #T_4baeb_row0_col3 {
#   background-color: #bddf26;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col4, #T_4baeb_row8_col4 {
#   background-color: #21a585;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col5, #T_4baeb_row1_col7 {
#   background-color: #2cb17e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col6, #T_4baeb_row0_col7, #T_4baeb_row1_col4, #T_4baeb_row9_col4 {
#   background-color: #25ab82;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col8 {
#   background-color: #4cc26c;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col9 {
#   background-color: #67cc5c;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col10, #T_4baeb_row0_col11 {
#   background-color: #58c765;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col12 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #20928c;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col13 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #1fa088;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row0_col14, #T_4baeb_row0_col15 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #1f988b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col0, #T_4baeb_row1_col2, #T_4baeb_row1_col3 {
#   background-color: #b8de29;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col5, #T_4baeb_row9_col5 {
#   background-color: #37b878;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col6, #T_4baeb_row6_col1, #T_4baeb_row9_col6, #T_4baeb_row9_col7 {
#   background-color: #2ab07f;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col8 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #69cd5b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col9 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #89d548;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col10, #T_4baeb_row1_col11 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #77d153;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col12 {
#   background-color: #21908d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col13 {
#   background-color: #20938c;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row1_col14, #T_4baeb_row1_col15, #T_4baeb_row9_col12 {
#   background-color: #20928c;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col0 {
#   background-color: #cde11d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col1, #T_4baeb_row9_col1 {
#   background-color: #d5e21a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col2 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #c5e021;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col3 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #c8e020;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col4, #T_4baeb_row5_col5, #T_4baeb_row9_col10, #T_4baeb_row9_col11 {
#   background-color: #5ec962;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col5 {
#   background-color: #70cf57;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col6, #T_4baeb_row2_col7, #T_4baeb_row8_col0 {
#   background-color: #65cb5e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col8, #T_4baeb_row5_col7 {
#   background-color: #52c569;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col9, #T_4baeb_row7_col6 {
#   background-color: #5ac864;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col10, #T_4baeb_row2_col11 {
#   background-color: #56c667;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col12 {
#   background-color: #24878e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col13, #T_4baeb_row9_col13 {
#   background-color: #228c8d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row2_col14, #T_4baeb_row2_col15 {
#   background-color: #23898e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col0, #T_4baeb_row7_col2, #T_4baeb_row7_col3 {
#   background-color: #8bd646;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col1 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #eae51a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col2 {
#   background-color: #b0dd2f;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col3, #T_4baeb_row5_col2, #T_4baeb_row5_col3 {
#   background-color: #b2dd2d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col4, #T_4baeb_row8_col3 {
#   background-color: #95d840;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col5 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #bade28;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col6, #T_4baeb_row3_col7 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #a5db36;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col8, #T_4baeb_row3_col10, #T_4baeb_row5_col11 {
#   background-color: #25ac82;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col9 {
#   background-color: #27ad81;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col11 {
#   background-color: #26ad81;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col12 {
#   background-color: #365d8d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col13, #T_4baeb_row7_col14, #T_4baeb_row7_col15 {
#   background-color: #3e4989;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col14 {
#   background-color: #3c4f8a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row3_col15 {
#   background-color: #3c508b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col0, #T_4baeb_row4_col5 {
#   background-color: #375b8d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col1 {
#   background-color: #423f85;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col2, #T_4baeb_row4_col3 {
#   background-color: #404688;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col4 {
#   background-color: #2f6c8e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col6, #T_4baeb_row4_col7, #T_4baeb_row7_col9 {
#   background-color: #33628d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col8, #T_4baeb_row6_col9 {
#   background-color: #472d7b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col9, #T_4baeb_row4_col13, #T_4baeb_row6_col14 {
#   background-color: #482979;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col10, #T_4baeb_row4_col11, #T_4baeb_row4_col14, #T_4baeb_row4_col15 {
#   background-color: #472a7a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row4_col12 {
#   background-color: #472c7a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col0 {
#   background-color: #a8db34;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col1 {
#   background-color: #d2e21b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col4 {
#   background-color: #4ec36b;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col6 {
#   background-color: #50c46a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col8 {
#   background-color: #4ac16d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col9 {
#   background-color: #1f9a8a;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col10 {
#   background-color: #23a983;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col12 {
#   background-color: #2a788e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col13 {
#   background-color: #365c8d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col14 {
#   background-color: #31668e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row5_col15 {
#   background-color: #31688e;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row6_col0 {
#   font-weight: bold;
#   font-color: black;
#   background-color: #cde11d;
#   color: #000000;
#   text-align: center;
# }
# #T_4baeb_row6_col2 {
#   background-color: #3aba76;
#   color: #000

# %%
pivot_df.to_excel('tables/ST1_full_benchmark.xlsx')
